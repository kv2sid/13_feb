# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.
# Note: Here Exception class refers to the base class for all the exceptions.
#
# Answer- All exceptions must be derives from the Baseclass. If a try statement with an except clause that mentions a particular class, that clause also handles any exception classes derived from that class (but not exception classes from which it is derived). Two exception classes that are not related via subclassing are never equivalent, even if they have the same name.
#
# The built-in exceptions is generated by the interpreter or built-in functions. Except where mentioned, they have an “associated value” indicating the detailed cause of the error. This may be a string or a tuple of several items of information (e.g., an error code and a string explaining the code). The associated value is usually passed as arguments to the exception class’s constructor.

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy.

# %%
# Define a function to recursively print exception hierarchy
def print_exception_hierarchy(exception_class, level=0):
    # Print the class name and indentation level
    print(" " * level + exception_class.__name__)
    
    # Recursively print subclasses
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, level + 2)

# Call the function with the base Exception class
print_exception_hierarchy(Exception)
# Out:
# Exception
#   TypeError
#     FloatOperation
#     MultipartConversionError
#   StopAsyncIteration
#   StopIteration
#   ImportError
#     ModuleNotFoundError
#     ZipImportError
#   OSError
#     ConnectionError
#       BrokenPipeError
#       ConnectionAbortedError
#       ConnectionRefusedError
#       ConnectionResetError
#         RemoteDisconnected
#     BlockingIOError
#     ChildProcessError
#     FileExistsError
#     FileNotFoundError
#     IsADirectoryError
#     NotADirectoryError
#     InterruptedError
#       InterruptedSystemCall
#     PermissionError
#     ProcessLookupError
#     TimeoutError
#     UnsupportedOperation
#     itimer_error
#     herror
#     gaierror
#     SSLError
#       SSLCertVerificationError
#       SSLZeroReturnError
#       SSLWantWriteError
#       SSLWantReadError
#       SSLSyscallError
#       SSLEOFError
#     Error
#       SameFileError
#     SpecialFileError
#     ExecError
#     ReadError
#     URLError
#       HTTPError
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
# Answer - The 'ArithemeticError class' is a base class for all errors that are occur during all arithematic operation. It is a subclass of 'exception' class. Moreover it is a parent class of many arithematic error such as.
# 1. zerodivision error
# 2. overflow error
# 3. floating point error
# 4. valueerror etc.

# %%
# zerodivision error
import logging
logging.basicConfig(filename = 'error.log', level = logging.ERROR)
try:
    a = 10
    b = 0
    c=a/b
except ZeroDivisionError as e:
    logging.error('This is my Zero division error {}'.format(e))
    print('This is my Zero division error :',e)
else:
    print(c)
# Out:
# This is my Zero division error : division by zero

# %%
# Value error
# trying to take the square root of a negative number

import logging
logging.basicConfig(filename = 'error1.log', level = logging.ERROR)

try:
    import math
    a = -1
    b = math.sqrt(a)    
except ValueError as e:
    logging.error('This is my vlaue error1{}'.format(e))
    print('This is my value error :',e)
else:
    print(b)
# Out:
# This is my value error : math domain error
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 17
#      15     print(b)
#      16 finally:
# ---> 17     error1.close()
#
# NameError: name 'error1' is not defined

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# Answer - A lookup class is a baseerror for two important class that are key error and Indexerror. KeyError is use in deictinory when the key of dictionary is not found in the dictionary. Whereas, the Indexerror is found into the list and tuple. When the desired element is not found into the list and tuple.

# %%
# example of keyError
import logging
logging.basicConfig(filename = 'error2.log',level = logging.ERROR)
try:
    fruit_dict = {1:'Apple',2:'Banana',3:'Guava',4:'Pineapple'}
    fruit_dict[5]
except KeyError as e:
    logging.error('This is my key error2 {}'.format(e))
    print('This is my keyerror2:', e)
else:
    print(fruit_dict[5])
# Out:
# This is my keyerror2: 5

# %%
# example of Indexerror
import logging
logging.basicConfig(filename = 'error3.log', level = logging.ERROR)
try:
    l1 = [1,2,3,4,5,6,7]
    l1[11]
except IndexError as e:
    logging.error('This is my Index error3 {}'.format(e))
    print('This is my index error3',e)
else:
    print(l1)
# Out:
# This is my index error3 list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?
#
# Answer - Import error is a type of error that occur in Python, when python is unable to import a module. It is raised when an import statement fails to locate requiste statement and load the requiste module.

# %%
logging.basicConfig(filename = 'error4.log', level = logging.ERROR)
try:
    import sidd
except ImportError as e:
    print(e)
# Out:
# No module named 'sidd'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.
#
# Answer - 1. Always write specific exception in the program.
# 2. Always write a spcific and correct message.
# 3. Always try to log
# 4. Always try to avoid to write multiple exception handling in program.
# 5. Prepare a proper documentation
# 6. cleanup all the resources
